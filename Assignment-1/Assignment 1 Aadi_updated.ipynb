# %% [markdown]
# # BASIC STATISTICS

# %% [markdown]
# # Descriptive Statistics & Data Preprocessing Sales and Discount Datasets

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\bommi\\OneDrive\\Desktop\\DATA_SCIENCE_ASSIGNMENTS\\Basic stats - 1 (1)\\Basic stats - 1\\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# 1        10100             101000          11.560498     11676.102961
# 2        16100             112700           9.456886     10657.910157
# 3        20100             120600           6.935385      8364.074702
# 4         8100              24300          17.995663      4372.946230
# ..         ...                ...                ...              ...
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501180
# 1       89323.897039
# 2      102042.089843
# 3      112235.925298
# 4       19927.053770
# ..               ...
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705
#
# [450 rows x 13 columns]

# %%
# To show top 5 rows

df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
# To show bottom 5 rows

df.tail()
# Out:
#            Date       Day  SKU City  Volume         BU  Brand      Model  \
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera  M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva  W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva   W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera  M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera    M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705

# %%
# To find the data types of the columns

df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %% [markdown]
# # Descriptive Analysis for Numerical Columns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# To find the Mean for Numerical data

df.mean(numeric_only=True)
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
# To find the Median for numerical data

df.median(numeric_only=True)
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
# To find the Mode for Numerical data

df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].mode().iloc[0]
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# Name: 0, dtype: float64

# %%
# To find the standard deviation for numerical columns

df.std(numeric_only=True)
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
#  Identify the Numerical columns in the data set 

numerical_columns = ['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']

# %%
# To calculate basic statistics for numerical columns

statistics = {'Mean': df[numerical_columns].mean(),
             'Median': df[numerical_columns].median(),
             'Mode': df[numerical_columns].mode().iloc[0],
             'Standard Deviation': df[numerical_columns].std()
}

# Converting to a Dataframe for better readaability

stats_df = pd.DataFrame(statistics)
print(stats_df)
# Out:
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %% [markdown]
# # Brief Interpretation of these statistics

# %% [markdown]
# # Volume (Units Sold per Transaction)

# %% [markdown]
# The average transaction involves 5.07 units, but the most common purchase size is 3 units.
# The median of 4 units suggests that many transactions are on the lower end.
# A standard deviation of 4.23 indicates moderate variability, meaning some larger purchases influence the average.

# %% [markdown]
# # Average Price per Unit ($)

# %% [markdown]
# The average price is 10,453, but the median price is much lower at 1,450, suggesting skewed pricing with some expensive items.
# The most frequently occurring price point is 400, indicating that lower-priced items dominate the sales.
# A high standard deviation of 18,079 confirms significant price variations.

# %% [markdown]
# # Total Sales Value per Transaction ($)

# %% [markdown]
# The average total sales value is 33,812, but the median is only 5,700, indicating that most transactions are much smaller.
# The mode of 24,300 suggests that some sales cluster around this value.
# A high standard deviation of 50,535 confirms that a few very large transactions are skewing the mean.

# %% [markdown]
# # Discount Rate (%)

# %% [markdown]
# The average discount applied is 15.16%, with a median of 16.58%.
# The most common discount rate is 5.01%, meaning some products receive minimal discounts.
# A standard deviation of 4.22% suggests relatively low variability in discount percentages.

# %% [markdown]
# # Discount Amount ($)

# %% [markdown]
# The average discount amount is 3,346, but the median is significantly lower at 988, meaning most discounts are smaller.
# The mode of 69 suggests that small discounts are the most frequent.
# A standard deviation of 4,509 indicates that some transactions receive very high discounts.

# %% [markdown]
# # Net Sales Value (After Discounts) ($)

# %% [markdown]
# The average net sales value is 30,466, but the median is just 4,677, suggesting that smaller transactions are more common.
# The mode of 326 indicates that many low-value transactions occur.
# A standard deviation of 46,358 highlights a wide range in net sales values, with some very high-value transactions pulling up the average.

# %% [markdown]
# # DATA VISUALIZATION

# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting up the plotting environment
plt.figure(figsize=(15, 10))

# Plot histograms for each numerical column
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 2, i)
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ANALYSIS

# %% [markdown]
# # Volume

# %% [markdown]
# Skewness : The mean is higher than the median, indicating a right-skewed distribution. This suggests that there are a number of transactions with higher volumes that are pulling the mean upward.
#
# Outliers : The high standard deviation (4.23) compared to the mean indicates that there is considerable variability in volume. This variability, along with the difference between the mean and median, suggests the presence of outliers.
#
# Inference : Most transactions are around 3 to 4 units, but there are some transactions with significantly higher volumes, which creates a right-skewed distribution.

# %% [markdown]
# # Average Price

# %% [markdown]
# Skewness : The mean is much higher than the median, indicating a significant right skew. This suggests that most prices are clustered around lower values (e.g., mode at 400), but there are a few very high prices that are skewing the mean.
#
# Outliers : The very high standard deviation compared to the mean implies that there are large fluctuations in the average price, likely due to some outliers.
#
# Inference : The data shows a concentration of lower prices with a few transactions at very high prices, creating a highly skewed distribution with potential outliers.

# %% [markdown]
# # Total Sales Value

# %% [markdown]
# Skewness : The mean is significantly higher than the median, which indicates a right-skewed distribution. This suggests that while most transactions have lower total sales values, a few transactions with very high values are increasing the mean.
#
# Outliers : The high standard deviation relative to the mean suggests significant variability and the presence of extreme values affecting the total sales value.
#
# Inference : The distribution is right-skewed with a concentration of lower values and some high-value transactions that create a long right tail.

# %% [markdown]
# # Discount Rate (%)

# %% [markdown]
# Skewness : The mean is slightly less than the median, suggesting a slight left skew. Most discount rates are clustered around higher values, with a lower frequency of very small discount rates.
#
# Outliers : The standard deviation is relatively small compared to the mean, suggesting less variability and fewer extreme values in discount rates.
#
# Inference : The discount rates are generally clustered around the median with a few occurrences of lower rates, indicating a somewhat uniform but slightly left-skewed distribution.

# %% [markdown]
# # Discount Amount

# %% [markdown]
# Skewness : The mean is much higher than the median, indicating a right-skewed distribution. This suggests that while most discount amounts are lower, some very high discounts are skewing the mean.
#
# Outliers : The large standard deviation relative to the mean indicates significant variability, likely due to the presence of outliers with very high discount amounts.
#
# Inference : The distribution is right-skewed with a concentration of lower discount amounts and some very high values affecting the mean.

# %% [markdown]
# # Net Sales Value

# %% [markdown]
# Skewness : The mean is significantly higher than the median, indicating a strong right skew. This implies that the majority of net sales values are much lower than the mean, with a few very high values skewing the distribution.
#
# Outliers : The extremely high standard deviation compared to the mean indicates that there are substantial outliers and extreme values in net sales.
#
# Inference : The net sales values show a right-skewed distribution with a concentration of lower values and several high-value transactions significantly influencing the mean.

# %% [markdown]
# # Box Plots

# %%
# Boxplots to identify outliers

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis

# %% [markdown]
# Skewed Distributions:
#
# Most variables appear to be right-skewed, indicated by the mean being higher than the median. This suggests that a few extreme values are pulling the mean upward.
#
# Outliers:
#
# Boxplots will likely show outliers, especially in Avg Price, Total Sales Value, and Net Sales Value. The extreme values can significantly influence the mean and standard deviation.
#
# Distribution Insights:
#
# The presence of skewness and outliers should be considered when performing further analysis or building models, as they can impact the interpretation and results.

# %% [markdown]
# # Bar Chart Analysis for Categorical Columns

# %%
# Identify categorical columns

categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
# Plot bar charts for categorical columns
for col in categorical_cols:
    plt.figure(figsize=(10, 6))
    df[col].value_counts().plot(kind='bar', color='skyblue')
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
    plt.show()

# %%
# insights for 'Model' column)

print(f"\nInsights for Model:\n{df['Model'].value_counts()}")
# Out:
# Insights for Model:
# Model
# RU-10             15
# RU-9 Plus         15
# M-Formals         15
# W-Lounge          15
# W-Western         15
# M-Casuals         15
# M-Jeans           15
# W-Inners          15
# W-Casuals         15
# M- Inners         15
# M- T Shirts       15
# Gear BB Cream     15
# Gear Shampoo      15
# Gear Cream        15
# Gear Oil          15
# Vedic Oil         15
# Babaji Cream      15
# Babaji Shampoo    15
# Vedic Shampoo     15
# Vedic Cream       15
# Babaji Oil        15
# O-11              15
# O-10              15
# S-21              15
# S-20              15
# RU-9              15
# YM-98             15
# YM-99 Plus        15
# YM-99             15
# M-Shoes           15
# Name: count, dtype: int64

# %%
# insights for 'Date' column

print(f"\nInsights for Date:\n{df['Date'].value_counts()}")
# Out:
# Insights for Date:
# Date
# 01-04-2021    30
# 02-04-2021    30
# 03-04-2021    30
# 04-04-2021    30
# 05-04-2021    30
# 06-04-2021    30
# 07-04-2021    30
# 08-04-2021    30
# 09-04-2021    30
# 10-04-2021    30
# 11-04-2021    30
# 12-04-2021    30
# 13-04-2021    30
# 14-04-2021    30
# 15-04-2021    30
# Name: count, dtype: int64

# %%
# insights for 'City' column

print(f"\nInsights for City:\n{df['City'].value_counts()}")
# Out:
# Insights for City:
# City
# C    450
# Name: count, dtype: int64

# %%
# insights for 'Day' column

print(f"\nInsights for Day:\n{df['Day'].value_counts()}")
# Out:
# Insights for Day:
# Day
# Thursday     90
# Friday       60
# Saturday     60
# Sunday       60
# Monday       60
# Tuesday      60
# Wednesday    60
# Name: count, dtype: int64

# %%
# insights for 'SKU' column

print(f"\nInsights for SKU:\n{df['SKU'].value_counts()}")
# Out:
# Insights for SKU:
# SKU
# M01    15
# M02    15
# L09    15
# L08    15
# L07    15
# L06    15
# L05    15
# L04    15
# L03    15
# L02    15
# L01    15
# F10    15
# F09    15
# F08    15
# F07    15
# F06    15
# F05    15
# F04    15
# F03    15
# F02    15
# F01    15
# M10    15
# M09    15
# M08    15
# M07    15
# M06    15
# M05    15
# M04    15
# M03    15
# L10    15
# Name: count, dtype: int64

# %%
# insights for 'Brand' column

print(f"\nInsights for Brand:\n{df['Brand'].value_counts()}")
# Out:
# Insights for Brand:
# Brand
# Jeera      90
# Gear       60
# Viva       60
# RealU      45
# YouM       45
# Babaji     45
# Vedic      45
# Sumsang    30
# Orange     30
# Name: count, dtype: int64

# %%
# insights for 'BU' column

print(f"\nInsights for BU:\n{df['BU'].value_counts()}")
# Out:
# Insights for BU:
# BU
# Mobiles      150
# FMCG         150
# Lifestyle    150
# Name: count, dtype: int64

# %% [markdown]
# # Standardization of Numerical Variables

# %% [markdown]
# Standardization, or z-score normalization, is a technique that rescales features to have a mean of 0 and a standard deviation of 1. It ensures that all features contribute equally to a machine learning model, improving convergence and performance. The formula for standardization is: 𝑧=(𝑥−𝜇)/𝜎 where x is the original value, μ is the mean, and σ is the standard deviation.

# %%
from scipy import stats
from sklearn.preprocessing import StandardScaler
from numpy import set_printoptions

# %%
standard = df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']].values
scaler = StandardScaler()
rescaledX=scaler.fit_transform(standard)

# %%
# Before Standardization

print(df[['Volume','Avg Price','Total Sales Value','Discount Rate (%)','Discount Amount','Net Sales Value']])
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501180
# 1       89323.897039
# 2      102042.089843
# 3      112235.925298
# 4       19927.053770
# ..               ...
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705
#
# [450 rows x 6 columns]

# %%
# After Standardization

print("\nAfter Standardization:")
set_printoptions(precision=2)
print(rescaledX[::])
# Out:
# After Standardization:
# [[ 2.35  0.09  2.93 -0.83  3.95  2.8 ]
#  [ 1.17 -0.02  1.33 -0.85  1.85  1.27]
#  [ 0.46  0.31  1.56 -1.35  1.62  1.55]
#  ...
#  [-0.73 -0.49 -0.61  0.9  -0.61 -0.6 ]
#  [-0.49 -0.47 -0.56  0.39 -0.53 -0.56]
#  [-0.96 -0.41 -0.61  0.04 -0.64 -0.6 ]]

# %% [markdown]
# # Conversion of Categorical data into Dummy Variables

# %%
# Identifying categorical columns in the dataset

categorical_columns = ['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model']

# %%
# Applying one-hot encoding

df_encoded = pd.get_dummies(df, columns=categorical_columns)
print(df_encoded.head())
# Out:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0    160346.501180             True            False            False
# 1     89323.897039             True            False            False
# 2    102042.089843             True            False            False
# 3    112235.925298             True            False            False
# 4     19927.053770             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# 0            False  ...              False            False
# 1            False  ...              False            False
# 2            False  ...              False            False
# 3            False  ...              False            False
# 4            False  ...              False            False
#
#    Model_Vedic Shampoo  Model_W-Casuals  Model_W-Inners  Model_W-Lounge  \
# 0                False            False           False           False
# 1                False            False           False           False
# 2                False            False           False           False
# 3                False            False           False           False
# 4                False            False           False           False
#
#    Model_W-Western  Model_YM-98   Model_YM-99  Model_YM-99 Plus
# 0            False         False        False             False
# 1            False         False        False             False
# 2            False         False         True             False
# 3            False         False        False              True
# 4            False          True        False             False
#
# [5 rows x 101 columns]

# %% [markdown]
# # SUMMARY

# %% [markdown]
# Need of One-hot encoding:
#
# One-hot encoding, also known as creating dummy variables, is the process of converting categorical data into a binary (0 or 1) format. This is essential for machine learning models, which typically require numerical input. One-hot encoding ensures that each category is represented by an independent binary variable, avoiding any implied ordinal relationships among categories and improving model performance by allowing algorithms to handle categorical features effectively

# %% [markdown]
# Standardization : Ensures numerical variables are on the same scale, improving model performance.
#
# One-Hot Encoding: Transforms categorical data into a suitable numerical format for ML algorithms.
